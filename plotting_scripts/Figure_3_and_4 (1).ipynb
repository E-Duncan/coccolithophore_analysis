
# ['Province_no', 'Score', 'SST', 'Wind speed mean', 'Wind speed std', 'Wind stress mean', 'Wind stress std', 'SLA', 'MLD', 'PAR']
# (1, 10)
# 100%|===================| 3989/4000 [05:24<00:00]        No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
# (2000, 8)
# [0.1038783817122501, 0.0542928322033536, 0.010098895716086704, 0.030266356399349697, 0.016851915555438416, 0.026656664400971735, 0.04243938083445553, 0.04139206783121499]
# ['Province_no', 'Score', 'SST', 'Wind speed mean', 'Wind speed std', 'Wind stress mean', 'Wind stress std', 'SLA', 'MLD', 'PAR']
# (1, 10)
# 100%|===================| 3988/4000 [04:39<00:00]        No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
# (2000, 8)
# [0.03272818800462089, 0.04321924406003326, 0.010001938018932652, 0.045451921483662776, 0.014545826829794358, 0.010470726238346668, 0.05830640128174242, 0.06981085977917924]
# ['Province_no', 'Score', 'SST', 'Wind speed mean', 'Wind speed std', 'Wind stress mean', 'Wind stress std', 'SLA', 'MLD', 'PAR']
# (1, 10)
# 100%|===================| 3992/4000 [06:48<00:00]        No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
# (2000, 8)
# [0.01750496200385202, 0.06677735603202847, 0.022111374012557753, 0.03869689312481489, 0.008759679833874988, 0.008199890868830436, 0.0403247433452977, 0.07428046977466317]
# ['Province_no', 'Score', 'SST', 'Wind speed mean', 'Wind speed std', 'Wind stress mean', 'Wind stress std', 'SLA', 'MLD', 'PAR']
# (1, 10)
# 100%|===================| 3992/4000 [06:49<00:00]        No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
# (2000, 8)
# [0.029947595662797016, 0.08232866332820535, 0.028543788047672703, 0.033688505819989376, 0.01713076015389985, 0.02608906714114248, 0.026203521602947425, 0.04996195973014766]
# ['Province_no', 'Score', 'SST', 'Wind speed mean', 'Wind speed std', 'Wind stress mean', 'Wind stress std', 'SLA', 'MLD', 'PAR']
# (1, 10)
# 100%|===================| 3997/4000 [06:27<00:00]        No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
# (2000, 8)
# [0.16548876650834263, 0.043491751433712665, 0.027108126287059123, 0.024124717750734204, 0.015258035618350372, 0.017935950944525617, 0.010189481268856803, 0.04891631635776729]
# ['Province_no', 'Score', 'SST', 'Wind speed mean', 'Wind speed std', 'Wind stress mean', 'Wind stress std', 'SLA', 'MLD', 'PAR']
# (1, 10)
# 100%|===================| 3991/4000 [05:53<00:00]        No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
# (2000, 8)
# [0.06857011913278337, 0.05288641326901089, 0.02368126102652467, 0.03215458630711133, 0.021664086200094725, 0.037151052653264204, 0.02635539314044991, 0.030962994001739647]
# ['Province_no', 'Score', 'SST', 'Wind speed mean', 'Wind speed std', 'Wind stress mean', 'Wind stress std', 'SLA', 'MLD', 'PAR']
# (1, 10)
# 100%|===================| 3999/4000 [06:16<00:00]        No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
# (2000, 8)
# [0.02871229401829522, 0.046394737701621704, 0.018984564275536544, 0.020274050767065503, 0.01008825647440868, 0.01721563456557832, 0.027360689540425743, 0.10615020790853227]
# ['Province_no', 'Score', 'SST', 'Wind speed mean', 'Wind speed std', 'Wind stress mean', 'Wind stress std', 'SLA', 'MLD', 'PAR']
# (1, 10)
# 100%|===================| 3999/4000 [06:43<00:00]        No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
# (2000, 8)
# [0.08121905153184011, 0.037319082081151075, 0.03420232284790711, 0.028799129090873326, 0.019405685304708712, 0.02385898310533088, 0.026542812103030833, 0.1028763992476874]
# ['Province_no', 'Score', 'SST', 'Wind speed mean', 'Wind speed std', 'Wind stress mean', 'Wind stress std', 'SLA', 'MLD', 'PAR']
# (1, 10)
# 100%|===================| 3993/4000 [07:05<00:00]        No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
# (2000, 8)
# [0.026411136414331144, 0.0685482065601679, 0.0054133362837779486, 0.04215828910054075, 0.01810869703753078, 0.02464402576886374, 0.059805171961109536, 0.09762440930029538]
# ['Province_no', 'Score', 'SST', 'Wind speed mean', 'Wind speed std', 'Wind stress mean', 'Wind stress std', 'SLA', 'MLD', 'PAR']
# (1, 10)
# 100%|===================| 3993/4000 [05:33<00:00]        No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
# (2000, 8)
# [0.10506050573808495, 0.016247863612124297, 0.006459808615522101, 0.008725687233275955, 0.013849387209414926, 0.008986933149944065, 0.03463860718683964, 0.06053955461065446]
# ['Province_no', 'Score', 'SST', 'Wind speed mean', 'Wind speed std', 'Wind stress mean', 'Wind stress std', 'SLA', 'MLD', 'PAR']
# (1, 10)

# %% [markdown]
# # Load SHAP results

# %%
df = pd.read_csv('/home/jovyan/lustre_scratch/Figures/model_shap_analysis_redo/model_analysis.csv')

# %%
df = df.set_index('Province_no')

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df2 = df.abs()

# %%
df2.drop(columns=['Score'],inplace=True)

# %%
# find maximum (highest ranking feature)
df['Feature_1'] = df2.idxmax(axis=1)

# %%
#fill maximum in each row with NaN
df2 = df2[df2.ne(df2.max(axis=1), axis=0)]

# %%
# replace NaN with 0
df2.fillna(0,inplace=True)

# %%
# find new maximum (second highest ranking feature)
df['Feature_2'] = df2.idxmax(axis=1)

# %%
df
# Out:
#                 Score       SST  Wind speed mean  Wind speed std  \
# Province_no
# 0.0          0.885979 -0.001062         0.000503        0.001369
# 1.0          0.711208 -0.003320        -0.002868       -0.000223
# 2.0          0.861901  0.002559         0.002071        0.003620
# 3.0          0.810811 -0.000792         0.012667       -0.001055
# 4.0          0.719364  0.001337        -0.002561        0.000315
# 5.0          0.598581  0.002039         0.000856        0.005970
# 10.0         0.739998 -0.002003        -0.006470        0.002441
# 15.0                -0.002069        -0.002006  0.002711  0.000317  0.015995
# 16.0                -0.001967        -0.004636  0.000343 -0.001485 -0.003592
# 17.0                -0.001780        -0.008551  0.000419 -0.001173 -0.020666
# 19.0                -0.001052         0.000859 -0.003748  0.000545 -0.010540
# 23.0                -0.005887         0.000875  0.000221  0.005934  0.016627
# 26.0                 0.002438        -0.003547 -0.003202 -0.005008 -0.003906
# 29.0                -0.009182        -0.002540  0.001152 -0.001537 -0.007123
# 30.0                 0.003752        -0.000913 -0.000361  0.000544  0.001871
# 31.0                -0.003886        -0.002234 -0.003758 -0.001822 -0.003853
# 32.0                 0.000903         0.002333 -0.000329 -0.002693 -0.001683
# 33.0                 0.000782         0.000998  0.001992 -0.003125  0.005537
# 42.0                -0.003059        -0.000577  0.002655  0.001543 -0.007611
# 43.0                -0.006914         0.000385 -0.001038 -0.005986  0.008538
# 51.0                -0.002664        -0.002522 -0.000735 -0.003226 -0.012812
# 52.0                 0.001450         0.001301  0.000532  0.004967  0.002118
# 0.0                  0.016241         0.033755  0.012643  0.038615  0.124886
# 1.0                  0.039023         0.015355  0.034071  0.022078  0.098237
# 2.0                  0.029015         0.019167  0.026359  0.042880  0.041448
# 3.0                  0.027059         0.026480  0.025373  0.031124  0.053386
# 3.0                  0.027555         0.026722  0.025692  0.031512  0.053311
# 4.0                  0.023991         0.024148  0.065968  0.020392  0.034424
# 5.0                  0.027031         0.038035  0.023663  0.018479  0.027301
# 10.0                 0.029535         0.023191  0.029502  0.017100  0.088701
# 11.0                 0.017828         0.027721  0.033213  0.017410  0.102428
# 14.0                 0.036625         0.038782  0.046238  0.053907  0.029152
# 15.0                 0.022247         0.016652  0.022910  0.016614  0.096201
# 16.0                 0.015061         0.048442  0.004771  0.041554  0.031195
# 17.0                 0.020705         0.030974  0.048470  0.010840  0.094334
# 19.0                 0.038503         0.009754  0.023759  0.031319  0.123528
# 23.0                 0.022609         0.017666  0.011988  0.031739  0.077927
# 26.0                 0.030266         0.016852  0.026657  0.042439  0.041392
# 29.0                 0.045452         0.014546  0.010471  0.058306  0.069811
# 30.0                 0.038697         0.008760  0.008200  0.040325  0.074280
# 31.0                 0.033689         0.017131  0.026089  0.026204  0.049962
# 32.0                 0.024125         0.015258  0.017936  0.010189  0.048916
# 33.0                 0.032155         0.021664  0.037151  0.026355  0.030963
# 42.0                 0.020274         0.010088  0.017216  0.027361  0.106150
# 43.0                 0.028799         0.019406  0.023859  0.026543  0.102876
# 51.0                 0.042158         0.018109  0.024644  0.059805  0.097624
# 52.0                 0.008726         0.013849  0.008987  0.034639  0.060540
#
#                     Feature_1
# Province_no
# 0.0                       PAR
# 1.0                       SLA
# 2.0                       MLD
# 3.0           Wind speed mean
# 4.0                       SLA
# 5.0            Wind speed std
# 10.0                      PAR
# 11.0          Wind speed mean
# 14.0           Wind speed std
# 3.0           Wind speed mean
# 15.0                      PAR
# 16.0          Wind speed mean
# 17.0                      PAR
# 19.0                      PAR
# 23.0                      SST
# 26.0          Wind speed mean
# 29.0         Wind stress mean
# 30.0          Wind speed mean
# 31.0          Wind speed mean
# 32.0                      SST
# 33.0                      PAR
# 42.0                      PAR
# 43.0                      PAR
# 51.0                      PAR
# 52.0                      SST
# 0.0                       PAR
# 1.0                       PAR
# 2.0           Wind speed mean
# 3.0           Wind speed mean
# 3.0           Wind speed mean
# 4.0                       SLA
# 5.0            Wind speed std
# 10.0                      PAR
# 11.0                      PAR
# 14.0                      MLD
# 15.0                      SST
# 16.0                      SST
# 17.0                      PAR
# 19.0                      PAR
# 23.0                      SST
# 26.0                      SST
# 29.0                      PAR
# 30.0                      PAR
# 31.0          Wind speed mean
# 32.0                      SST
# 33.0                      SST
# 42.0                      PAR
# 43.0                      PAR
# 51.0                      PAR
# 52.0                      SST

# %%
df = df.iloc[25:,:] #remove repeated

# %%
three = df.iloc[3] #remove incorrectly labelled province

# %%
df = df.drop([3])

# %%
df = df.append(three)
# Out:
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
df
# Out:
#                 Score       SST  Wind speed mean  Wind speed std  \
# Province_no
# 0.0          0.885979  0.044128         0.009126        0.027160
# 1.0          0.711208  0.027235         0.075765        0.012786
# 2.0          0.861901  0.041025         0.056226        0.013143
# 4.0          0.719364  0.033960         0.042448        0.035305
# 5.0          0.598581  0.030901         0.019465        0.057561
# 10.0         0.739998  0.026456         0.020355        0.042305
# 11.0         0.779398  0.046550         0.075010        0.036042
# 14.0         0.695966  0.036763         0.030397        0.030474
# 15.0         0.707685  0.107482         0.038991        0.014339
# 16.0         0.853796  0.073289         0.027333        0.053738
# 17.0         0.793004  0.054825         0.039172        0.052649
# 19.0         0.753118  0.041484         0.029907        0.007934
# 23.0         0.801280  0.109183         0.066862        0.071206
# 26.0         0.878685  0.103878         0.054293        0.010099
# 29.0         0.870654  0.032728         0.043219        0.010002
# 30.0         0.781739  0.017505         0.066777        0.022111
# 31.0         0.773640  0.029948         0.082329        0.028544
# 32.0         0.722549  0.165489         0.043492        0.027108
# 33.0         0.743994  0.068570         0.052886        0.023681
# 42.0         0.745483  0.028712         0.046395        0.018985
# 43.0         0.701920  0.081219         0.037319        0.034202
# 51.0         0.757541  0.026411         0.068548        0.005413
# 52.0         0.879129  0.105061         0.016248        0.006460
# 3.0          0.810811  0.027454         0.085678        0.014354
#
#              Wind stress mean  Wind stress std       SLA       MLD       PAR  \
# Province_no
# 0.0                  0.016241         0.033755  0.012643  0.038615  0.124886
# 1.0                  0.039023         0.015355  0.034071  0.022078  0.098237
# 2.0                  0.029015         0.019167  0.026359  0.042880  0.041448
# 4.0                  0.023991         0.024148  0.065968  0.020392  0.034424
# 5.0                  0.027031         0.038035  0.023663  0.018479  0.027301
# 10.0                 0.029535         0.023191  0.029502  0.017100  0.088701
# 11.0                 0.017828         0.027721  0.033213  0.017410  0.102428
# 14.0                 0.036625         0.038782  0.046238  0.053907  0.029152
# 15.0                 0.022247         0.016652  0.022910  0.016614  0.096201
# 16.0                 0.015061         0.048442  0.004771  0.041554  0.031195
# 17.0                 0.020705         0.030974  0.048470  0.010840  0.094334
# 19.0                 0.038503         0.009754  0.023759  0.031319  0.123528
# 23.0                 0.022609         0.017666  0.011988  0.031739  0.077927
# 26.0                 0.030266         0.016852  0.026657  0.042439  0.041392
# 29.0                 0.045452         0.014546  0.010471  0.058306  0.069811
# 30.0                 0.038697         0.008760  0.008200  0.040325  0.074280
# 31.0                 0.033689         0.017131  0.026089  0.026204  0.049962
# 32.0                 0.024125         0.015258  0.017936  0.010189  0.048916
# 33.0                 0.032155         0.021664  0.037151  0.026355  0.030963
# 42.0                 0.020274         0.010088  0.017216  0.027361  0.106150
# 43.0                 0.028799         0.019406  0.023859  0.026543  0.102876
# 51.0                 0.042158         0.018109  0.024644  0.059805  0.097624
# 52.0                 0.008726         0.013849  0.008987  0.034639  0.060540
# 3.0                  0.027059         0.026480  0.025373  0.031124  0.053386
#
#                    Feature_1        Feature_2
# Province_no
# 0.0                      PAR              SST
# 1.0                      PAR  Wind speed mean
# 2.0          Wind speed mean              MLD
# 4.0                      SLA  Wind speed mean
# 5.0           Wind speed std  Wind stress std
# 10.0                     PAR   Wind speed std
# 11.0                     PAR  Wind speed mean
# 14.0                     MLD              SLA
# 15.0                     SST              PAR
# 16.0                     SST   Wind speed std
# 17.0                     PAR              SST
# 19.0                     PAR              SST
# 23.0                     SST              PAR
# 26.0                     SST  Wind speed mean
# 29.0                     PAR              MLD
# 30.0                     PAR  Wind speed mean
# 31.0         Wind speed mean              PAR
# 32.0                     SST              PAR
# 33.0                     SST  Wind speed mean
# 42.0                     PAR  Wind speed mean
# 43.0                     PAR              SST
# 51.0                     PAR  Wind speed mean
# 52.0                     SST              PAR
# 3.0          Wind speed mean              PAR

# %% [markdown]
# # Load province file

# %%
#Load in longhurst shape file

import fiona
mask_path = '/data/datasets/Projects/TuringCoccolithophoreBlooms/province_files/Longhurst_world_v4_2010.shp'
shapefile = fiona.open(mask_path)

with fiona.open(mask_path) as shapefile:
    shapes = [feature["geometry"] for feature in shapefile]

# %%
type(shapes[1])
# Out:
# dict

# %%
colors = {'SST':'#E45756',
          'Wind speed mean':'#72B7B2',
          'Wind speed std':'#54A24B',
          'Wind stress mean':'#FF9DA6',
          'Wind stress std':'#B279A2',
          'SLA':'#F58518', 
          'MLD':'#4C78A8',
          'PAR':'#EECA3B'}

# %%
from shapely.geometry import LineString, MultiPolygon, shape, box

# %%
import matplotlib.pyplot as plt 
from descartes import PolygonPatch
import cartopy.feature as cfeat
import matplotlib.patches as mpatches
plt.figure()
# Define the figure and each axis
fig, axs = plt.subplots(nrows=1,ncols=1,
                        subplot_kw={'projection': ccrs.PlateCarree()},figsize=(11,8.5))



ax = axs
for i in range(0,len(df)): #,p in enumerate(provinces):
    p = int(df.index[i])

    if p==2:
        nor = box(shape(shapes[p]).bounds[0], shape(shapes[p]).bounds[1], 10, shape(shapes[p]).bounds[3])
        bar = box(10, shape(shapes[p]).bounds[1], shape(shapes[p]).bounds[2], shape(shapes[p]).bounds[3])
        print(shape(shapes[p]).bounds)

        norw_patch = shape(shapes[p]).intersection(nor)
        bar_patch = shape(shapes[p]).intersection(bar)

        ax.add_patch(PolygonPatch(norw_patch, fc=colors['Wind speed mean']))
        ax.add_patch(PolygonPatch(bar_patch, fc=colors['SST']))
        
    else:
        print(df[df.Feature_1[p]][p])
        ax.add_patch(PolygonPatch(shapes[p], fc=colors[df.Feature_1[p]]))
        
        ax.axis('scaled')


ax.add_feature(cfeat.LAND,color='lightgrey')
ax.add_feature(cfeat.COASTLINE)
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,linewidth=0.33, color='k',alpha=0.5)
gl.xlabels_bottom = False
gl.ylabels_right = False
# create the colourbar
ax.set_xlim([-180,180])
ax.set_ylim([-90,90])
plt.legend([mpatches.Patch(color=colors[c]) for c in colors],
           [key for key in colors])

plt.savefig('Feature_map_1.png')
# Out:
# 0
# 0.1248859807415019
# 1
# 0.0982369111167181
# 2
# (-23.499999999999886, 57.50000000000006, 50.50000000000023, 75.50000000000023)
# 4
# 0.0659680027615588
# 5
# 0.0575610848403185
# 10
# 0.0887008888977231
# Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
# The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
# The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
# 11
# 0.1024276501059371
# 14
# 0.0539072752387033
# 15
# 0.1074821928522567
# 16
# 0.0732891907967867
# 17
# 0.0943340555555516
# 19
# 0.123527668970002
# 23
# 0.1091834196460394
# 26
# 0.1038783817122501
# 29
# 0.0698108597791792
# 30
# 0.0742804697746631
# 31
# 0.0823286633282053
# 32
# 0.1654887665083426
# 33
# 0.0685701191327833
# 42
# 0.1061502079085322
# 43
# 0.1028763992476874
# 51
# 0.0976244093002953
# 52
# 0.1050605057380849
# 3
# 0.0856779051862442
# The .xlabels_bottom attribute is deprecated. Please use .bottom_labels to toggle visibility instead.
# The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.

# %%
import matplotlib.pyplot as plt 
from descartes import PolygonPatch
import cartopy.feature as cfeat

plt.figure()
# Define the figure and each axis
fig, axs = plt.subplots(nrows=1,ncols=1,
                        subplot_kw={'projection': ccrs.PlateCarree()},figsize=(11,8.5))



ax = axs
for i in range(0,len(df)): #,p in enumerate(provinces):
    p = int(df.index[i])

    if p==2:
        nor = box(shape(shapes[p]).bounds[0], shape(shapes[p]).bounds[1], 10, shape(shapes[p]).bounds[3])
        bar = box(10, shape(shapes[p]).bounds[1], shape(shapes[p]).bounds[2], shape(shapes[p]).bounds[3])
        print(shape(shapes[p]).bounds)

        norw_patch = shape(shapes[p]).intersection(nor)
        bar_patch = shape(shapes[p]).intersection(bar)

        ax.add_patch(PolygonPatch(norw_patch, fc=colors['PAR']))
        ax.add_patch(PolygonPatch(bar_patch, fc=colors['PAR']))
        
    else:

        ax.add_patch(PolygonPatch(shapes[p], fc=colors[df.Feature_2[p]]))
        ax.axis('scaled')


ax.add_feature(cfeat.LAND,color='lightgrey')
ax.add_feature(cfeat.COASTLINE)
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,linewidth=0.33, color='k',alpha=0.5)
gl.xlabels_bottom = False
gl.ylabels_right = False
# create the colourbar
ax.set_xlim([-180,180])
ax.set_ylim([-90,90])
plt.legend([mpatches.Patch(color=colors[c]) for c in colors],
           [key for key in colors])

plt.savefig('Feature_map_2.png')
# Out:
# 0
# 1
# 2
# (-23.499999999999886, 57.50000000000006, 50.50000000000023, 75.50000000000023)
# 4
# 5
# 10
# 11
# 14
# 15
# 16
# 17
# 19
# 23
# 26
# 29
# 30
# 31
# 32
# 33
# 42
# 43
# 51
# 52
# 3
